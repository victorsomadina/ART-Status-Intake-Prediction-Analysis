# %% [markdown]
# ### Loading Libraries and Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from faker import Faker
import random
import re
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from category_encoders import BinaryEncoder

#pd.set_option("display.max_column", None)
import warnings
warnings.filterwarnings('ignore')

# %%
# Load the Dataset
df = pd.read_csv(r"C:\Users\hp\Downloads\WEEK 174 Delta STATE LINELIST.csv")

# %%
# show distribution of target variable
df['CurrentARTStatus'].value_counts()
# Out:
# CurrentARTStatus
# Active               73488
# LTFU                 24183
# Discontinued Care     7116
# Transferred out       3168
# Death                 2530
# Name: count, dtype: int64

# %% [markdown]
# #### Data Anonymization

# %%
# Initialize faker function
fake = Faker()

# %%
def anonymize_data(df):
    ''' This function creates fake observations and apply to respective variable names'''
    df['Patient_Name'] = df['Patient_Name'].apply(lambda x: fake.name())
    df['ART_ID'] = df['ART_ID'].apply(lambda x: fake.phone_number())
    df['Patient_Address'] = df['Patient_Address'].apply(lambda x: fake.address().replace('\n', ' '))
    df['Patient_LGA'] = df['Patient_LGA'].apply(lambda x: fake.address().replace('\n', ' '))
    return df

anonymized_df = anonymize_data(df)

# %%
data = anonymized_df
data
# Out:
#           IP  State                 Facility_Name   Datim_Code  \
# 0       CCFN  Delta  de General Hospital Orerokpe  YVvZ4NOLpBr
# 1       CCFN  Delta  de General Hospital Orerokpe  YVvZ4NOLpBr
# 2       CCFN  Delta  de General Hospital Orerokpe  YVvZ4NOLpBr
# 3       CCFN  Delta  de General Hospital Orerokpe  YVvZ4NOLpBr
# 4       CCFN  Delta  de General Hospital Orerokpe  YVvZ4NOLpBr
# ...      ...    ...                           ...          ...
# 110480  CCFN  Delta     de Agbor Central Hospital  HFp2lb9f404
# 110481  CCFN  Delta     de Agbor Central Hospital  HFp2lb9f404
# 110482  CCFN  Delta     de Agbor Central Hospital  HFp2lb9f404
# 110483  CCFN  Delta     de Agbor Central Hospital  HFp2lb9f404
# 110484  CCFN  Delta     de Agbor Central Hospital  HFp2lb9f404
#
#                       ART_ID HospitalNo Sex        DOB  current_Age  \
# 0           869-353-6611x171      31724   M   1-Jan-75         47.0
# 1          (883)724-7773x350   KGH37152   F   1-Jan-89         33.0
# 2          (475)327-2157x798      31683   M   1-Jan-68         54.0
# 3               811.307.5336   KGH37154   F   1-Jan-87         35.0
# 4               559.508.7048      31656   F   1-Jan-55         67.0
# ...                      ...        ...  ..        ...          ...
# 110480       +1-743-530-7404      10929   M   2-Jun-83         39.0
# 110481      001-395-913-6457      10840   M  20-Jan-70         52.0
# 110482          377.902.4436      10930   M  15-Aug-85         37.0
# 110483      001-964-979-7249      10931   F  18-Nov-89         32.0
# 110484  001-397-291-9144x118      10932   F   7-Oct-92         29.0
#
#               Patient_Name  ... Appointment_Status Next_Visit_Date  \
# 0       Danielle Patterson  ...  Active With Drugs        6-Sep-22
# 1           Gabriel Lester  ...               LTFU       13-Jul-16
# 2              Tommy Lewis  ...  Active With Drugs       11-Oct-22
# 3          Michael Hammond  ...               LTFU       27-Jul-20
# 4          Julie Rodriguez  ...  Active With Drugs       25-Oct-22
# ...                    ...  ...                ...             ...
# 110480       Charles Lopez  ...  Active With Drugs       22-Nov-22
# 110481        Michael Dunn  ...               LTFU             NaN
# 110482          Sean Hodge  ...               LTFU             NaN
# 110483    Alyssa Gallagher  ...  Active With Drugs       22-Nov-22
# 110484         Denise Park  ...  Active With Drugs       24-Nov-22
#
#        Next_Ap_by_pharmPill Next_Ap_by_careCard Days_To_Schedule  \
# 0                  6-Sep-22            6-Sep-22             12.0
# 1                       NaN                 NaN          -2234.0
# 2                 11-Oct-22           11-Oct-22             47.0
# 3                       NaN           23-Jul-20           -759.0
# 4                 25-Oct-22           25-Oct-22             61.0
# ...                     ...                 ...              ...
# 110480            22-Nov-22           25-Nov-22             85.0
# 110481                  NaN                 NaN              NaN
# 110482                  NaN                 NaN              NaN
# 110483            22-Nov-22           23-Nov-22             85.0
# 110484            24-Nov-22           25-Nov-22             87.0
#
#         TransferInStatus TransferInDate Biometric_Status Biometric_date  \
# 0                    NaN            NaN              Yes       1/7/2021
# 1                    NaN            NaN               No            NaN
# 2                    NaN            NaN              Yes       2/4/2021
# 3                    NaN            NaN               No            NaN
# 4                    NaN            NaN              Yes       5/5/2021
# ...                  ...            ...              ...            ...
# 110480               NaN            NaN              Yes      8/24/2022
# 110481               NaN            NaN               No            NaN
# 110482               NaN            NaN              Yes      8/25/2022
# 110483               NaN            NaN              Yes      8/25/2022
# 110484               NaN            NaN              Yes      8/26/2022
#
#          Date_Generated
# 0       8/25/2022 19:25
# 1       8/25/2022 19:25
# 2       8/25/2022 19:25
# 3       8/25/2022 19:25
# 4       8/25/2022 19:25
# ...                 ...
# 110480   8/29/2022 9:58
# 110481   8/29/2022 9:58
# 110482   8/29/2022 9:58
# 110483   8/29/2022 9:58
# 110484   8/29/2022 9:58
#
# [110485 rows x 61 columns]

# %% [markdown]
# ### EDA and Data Cleaning

# %%
def clean_data(data):
    ''' This function cleans some of the basic irregularities in the dataset such as datatype structuring, filling null values'''
    # drop irrelevant columns 
    data.drop(['Age_in_months', 'setting', 'DOB', 'Facility_Name', 
               'IP', 'Datim_Code', 'HospitalNo','Patient_LGA',
               'Patient_State', 'State', 'Phone_No', 'Patient_Name', 
               'Patient_Address'], axis = 1, inplace = True)
    
    # convert selected columns to datetime datatype
    conv_to_datetime = ['EnrollmentDate', 'ART_Start_Date', 'ViralLoadReportedDate', 'Clinic_Visit_Lastdate', 'Pharmacy_LastPickupdate',
                        'stamp_date', 'DateofCurrentViralLoad', 'ViralLoadReportedDate', 'LastDateOfSampleCollection', 'TBStatusDate',
                        'INHStartDate',	'INHStopDate',	'LastINHDispensedDate',	'TBTreatmentStartDate',	'TBTreatmentStopDate',	
                        'OTZStartDate',	'OTZStopDate', 'DateofFirstDTGPickup', 'Termination_Date', 'Next_Visit_Date',	
                        'Next_Ap_by_pharmPill',	'Next_Ap_by_careCard', 'Biometric_date', 'Date_Generated', 'CurrentHeightDate', 'CurrentWeightDate']
    for col in conv_to_datetime:
        data[col] = pd.to_datetime(data[col], errors = 'coerce')
        
    # Convert to integer
    conv_to_int = ['current_Age', 'Age_At_Start', 'DaysOfARVRefill', 'CurrentViralLoad', 'CurrentWeight_Kg', 'CurrentHeight_Kg', 'Days_To_Schedule']
    for cols in conv_to_int:
        data[cols] = pd.to_numeric(data[cols], errors = 'coerce')  

    # rename columns 
    data.rename(columns={'CurrentHeight_Kg': 'CurrentHeight_cm'}, inplace=True)

    # Change Sex columns to Male and Female
    data['Sex'].replace({"F":'Female', 'M':'Male'}, inplace = True)
    
    return data

data = clean_data(data)

# %%
data
# Out:
#                       ART_ID     Sex  current_Age  Age_At_Start  \
# 0           869-353-6611x171    Male         47.0          42.0
# 1          (883)724-7773x350  Female         33.0          27.0
# 2          (475)327-2157x798    Male         54.0          49.0
# 3               811.307.5336  Female         35.0          30.0
# 4               559.508.7048  Female         67.0          62.0
# ...                      ...     ...          ...           ...
# 110480       +1-743-530-7404    Male         39.0          30.0
# 110481      001-395-913-6457    Male         52.0           NaN
# 110482          377.902.4436    Male         37.0           NaN
# 110483      001-964-979-7249  Female         32.0          32.0
# 110484  001-397-291-9144x118  Female         29.0          29.0
#
#        EnrollmentDate ART_Start_Date Clinic_Visit_Lastdate  \
# 0          2017-08-03     2017-08-03            2022-03-10
# 1          2016-06-13     2016-06-13            2016-06-13
# 2          2017-06-29     2017-06-29            2022-04-14
# 3          2017-03-16     2017-03-17            2020-04-28
# 4          2017-05-25     2017-05-25            2022-04-28
# ...               ...            ...                   ...
# 110480     2013-10-02     2013-10-02            2022-08-24
# 110481     2022-05-11            NaT                   NaT
# 110482     2022-08-24            NaT                   NaT
# 110483     2022-08-24     2022-08-24            2022-08-24
# 110484     2022-08-26     2022-08-26            2022-08-26
#
#        Pharmacy_LastPickupdate          stamp_date  DaysOfARVRefill  ...  \
# 0                   2022-03-10 2022-03-11 12:57:00            180.0  ...
# 1                   2016-06-13 2017-09-28 00:00:00             14.0  ...
# 2                   2022-04-14 2022-04-14 11:34:00            180.0  ...
# 3                   2020-04-28 2020-05-01 10:37:00             90.0  ...
# 4                   2022-04-28 2022-04-28 15:34:00            180.0  ...
# ...                        ...                 ...              ...  ...
# 110480              2022-08-24 2022-08-24 15:07:00             90.0  ...
# 110481                     NaT                 NaT              NaN  ...
# 110482                     NaT                 NaT              NaN  ...
# 110483              2022-08-24 2022-08-25 09:38:00             90.0  ...
# 110484              2022-08-26 2022-08-26 15:26:00             90.0  ...
#
#        Appointment_Status Next_Visit_Date Next_Ap_by_pharmPill  \
# 0       Active With Drugs      2022-09-06           2022-09-06
# 1                    LTFU      2016-07-13                  NaT
# 2       Active With Drugs      2022-10-11           2022-10-11
# 3                    LTFU      2020-07-27                  NaT
# 4       Active With Drugs      2022-10-25           2022-10-25
# ...                   ...             ...                  ...
# 110480  Active With Drugs      2022-11-22           2022-11-22
# 110481               LTFU             NaT                  NaT
# 110482               LTFU             NaT                  NaT
# 110483  Active With Drugs      2022-11-22           2022-11-22
# 110484  Active With Drugs      2022-11-24           2022-11-24
#
#        Next_Ap_by_careCard Days_To_Schedule  TransferInStatus TransferInDate  \
# 0               2022-09-06             12.0               NaN            NaN
# 1                      NaT          -2234.0               NaN            NaN
# 2               2022-10-11             47.0               NaN            NaN
# 3               2020-07-23           -759.0               NaN            NaN
# 4               2022-10-25             61.0               NaN            NaN
# ...                    ...              ...               ...            ...
# 110480          2022-11-25             85.0               NaN            NaN
# 110481                 NaT              NaN               NaN            NaN
# 110482                 NaT              NaN               NaN            NaN
# 110483          2022-11-23             85.0               NaN            NaN
# 110484          2022-11-25             87.0               NaN            NaN
#
#        Biometric_Status Biometric_date      Date_Generated
# 0                   Yes     2021-01-07 2022-08-25 19:25:00
# 1                    No            NaT 2022-08-25 19:25:00
# 2                   Yes     2021-02-04 2022-08-25 19:25:00
# 3                    No            NaT 2022-08-25 19:25:00
# 4                   Yes     2021-05-05 2022-08-25 19:25:00
# ...                 ...            ...                 ...
# 110480              Yes     2022-08-24 2022-08-29 09:58:00
# 110481               No            NaT 2022-08-29 09:58:00
# 110482              Yes     2022-08-25 2022-08-29 09:58:00
# 110483              Yes     2022-08-25 2022-08-29 09:58:00
# 110484              Yes     2022-08-26 2022-08-29 09:58:00
#
# [110485 rows x 48 columns]

# %% [markdown]
# ### Treating Null Values: Numerical Variables

# %%
# calculate null percentage and drop columns above 50% null percentage
cols_above_50 = []
for cols in data.columns:
    null_percentage = data[cols].isnull().mean()*100
    if null_percentage > 50:
        cols_above_50.append(cols)
print(cols_above_50)

# drop these columns
data.drop(cols_above_50, axis = 1, inplace = True)
# Out:
# ['CurrentPregnancyStatus', 'INHStopDate', 'LastINHDispensedDate', 'TBTreatmentStartDate', 'TBTreatmentStopDate', 'OTZStartDate', 'OTZStopDate', 'Termination_Reason', 'Termination_Date', 'TransferInStatus', 'TransferInDate']

# %%
# fill numerical null values with median
num_null_list = list(data.select_dtypes(['int', 'float']).isnull().sum().index)

# Calculate medians for each category
for col in num_null_list:
    medians = data.groupby('CurrentARTStatus')[col].median()
    # Fill null values with corresponding medians
    data[col].fillna(df['CurrentARTStatus'].map(medians), inplace=True)

# %%
# perform a descriptive statistics
data.select_dtypes(['float', 'int']).describe()
# Out:
#          current_Age   Age_At_Start  DaysOfARVRefill  CurrentViralLoad  \
# count  110485.000000  110485.000000    110485.000000      1.104850e+05
# mean       37.398488      32.628384       128.750699      6.545202e+03
# std        13.029183      11.563284        62.064970      3.241902e+05
# min         0.000000       0.000000         1.000000      0.000000e+00
# 25%        28.000000      25.000000        90.000000      5.000000e+00
# 50%        36.000000      32.000000       180.000000      1.900000e+01
# 75%        45.000000      39.000000       180.000000      3.000000e+01
# max       119.000000     113.000000       180.000000      1.000000e+08
#
#        CurrentWeight_Kg  CurrentHeight_cm  Days_To_Schedule
# count     110485.000000     110485.000000     110485.000000
# mean          62.307925        163.093785       -485.391976
# std           14.868997         15.239681       1038.612252
# min            0.000000          5.000000      -7301.000000
# 25%           56.000000        160.000000       -534.000000
# 50%           61.000000        163.000000         43.000000
# 75%           70.000000        170.000000         92.000000
# max          250.000000        270.000000        180.000000

# %%
# Check distribution of the numerical variables
for col in data.select_dtypes(['int', 'float']):
    print(col)
    plt.boxplot(data[col])
    plt.show()
# Out:
# current_Age
# Age_At_Start
# DaysOfARVRefill
# CurrentViralLoad
# CurrentWeight_Kg
# CurrentHeight_cm
# Days_To_Schedule

# %%
# eliminate outlier in current viral load column: implement IQR
#data['CurrentViralLoad']
q1, q3 = np.percentile(data['CurrentViralLoad'], [25, 75])
IQR = q3 - q1

lower_bound = q1 - 3 * IQR
upper_bound = q3 + 3 * IQR

print(lower_bound)
print(upper_bound)

# Retrieve median of IQR and fill outliers with those values 
non_outlier_median = data[~(data['CurrentViralLoad'] < lower_bound) | (data['CurrentViralLoad'] > upper_bound)]['CurrentViralLoad'].median()
data.loc[(data['CurrentViralLoad'] < lower_bound) | (data['CurrentViralLoad'] > upper_bound), 'CurrentViralLoad'] = non_outlier_median
# Out:
# -70.0
# 105.0

# %%
# check distribution of numerical variables 
data.select_dtypes(['int', 'float']).hist()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Treating Nulls: Categorical Variables

# %%
# Show unique values in categorical features
categorical_features = ['Sex', 'CurrentRegimenLine', 'TBStatus', 'Appointment_Status',
                       'RegimenLineAtARTStart',	'RegimenAtARTStart', 'CurrentARTRegimen', 'ViralLoadIndication', 'DTGFirstPickUp',	
                       'CurrentARTStatus',	'Biometric_Status']
for feature in categorical_features:
    print(f"{data[feature].value_counts()}\n")
# Out:
# Sex
# Female    63931
# Male      46552
# Name: count, dtype: int64
#
# CurrentRegimenLine
# Adult 1st line ARV regimen     98205
# Child 1st line ARV regimen      1933
# Adult 2nd line ARV regimen      1208
# Child 2nd line ARV regimen       100
# Adult 3rd Line ARV Regimens       27
# One                               24
# Two                                1
# Child 3rd Line ARV Regimens        1
# AZT-3TC-DTG                        1
# Name: count, dtype: int64
#
# TBStatus
# No signs or symptoms of disease    97519
# Currently on INH prophylaxis        1460
# Disease suspected                   1129
# On treatment for disease             269
# Completed treatment for disease      251
# Disease diagnosed                    105
# 27-Jul-22                              1
# Name: count, dtype: int64
#
# Appointment_Status
# Active With Drugs     71483
# LTFU                  36481
# Missed Appointment     2502
# Today Visit              19
# Name: count, dtype: int64
#
# RegimenLineAtARTStart
# Adult 1st line ARV regimen     98994
# Child 1st line ARV regimen      1617
# Adult 2nd line ARV regimen       408
# Child 2nd line ARV regimen       373
# Adult 3rd Line ARV Regimens      102
# One                                4
# Three                              1
# 30                                 1
# Name: count, dtype: int64
#
# RegimenAtARTStart
# TDF-3TC-DTG                   61136
# TDF-3TC-EFV                   22253
# AZT-3TC-NVP                    9940
# TDF-FTC-EFV                    2313
# TDF-3TC-NVP                    1283
# AZT-3TC-EFV                     855
# D4T-3TC-NVP                     528
# TDF-FTC-NVP                     405
# TDF-3TC-LPV/r                   383
# TDF-FTC-DTG                     327
# ABC-3TC-DTG                     273
# ABC-3TC-LPV/r                   245
# TDF-3TC-ATV/r                   241
# AZT-3TC-DTG                     217
# ABC-3TC-NVP                     121
# ABC-3TC-EFV                     112
# D4T-3TC-EFV                      70
# AZT-TDF-NVP                      59
# AZT-3TC-LPV/r                    42
# TDF-3TC-AZT                      31
# TDF-FTC-LPV/r                    18
# ABC-FTC-NVP                      14
# TDF-FTC-ATV/r                    13
# ABC-3TC-ATV/r                    13
# DDI-3TC-EFV                       7
# ABC-3TC-AZT                       7
# AZT-TDF-3TC-LPV/r                 5
# DDI-3TC-NVP                       5
# AZT-TDF-FTC-LPV/r                 4
# TDF-AZT-3TC-ATV/r                 4
# Dolutegravir                      3
# AZT-3TC-ATV/r                     3
# NEVIRAPINE/ZIDOVUDINE             2
# D4T-3TC-ABC                       2
# TDF-3TC-IDV/r                     2
# TDF-FTC-AZT-ATV/r                 2
# TDF-FTC-IDV/r                     1
# TDF-3TC-DTG-LPV/r                 1
# Adult 1st line ARV regimen        1
# ABC-AZT-LPV/r                     1
# AZT-3TC-SQV/r                     1
# TDF-3TC-DRV/r                     1
# TDF-AZT-3TC-IDV/r                 1
# TDF-DDI-IDV/r                     1
# ABC-3TC-DDI                       1
# D4T-3TC-LPV/r                     1
# Name: count, dtype: int64
#
# CurrentARTRegimen
# TDF-3TC-DTG                   80498
# TDF-3TC-EFV                    8041
# AZT-3TC-NVP                    4901
# ABC-3TC-DTG                    1402
# TDF-FTC-EFV                     684
# TDF-3TC-NVP                     543
# TDF-3TC-ATV/r                   537
# AZT-3TC-EFV                     472
# AZT-3TC-ATV/r                   228
# ABC-3TC-ATV/r                   218
# D4T-3TC-NVP                     172
# TDF-FTC-NVP                     161
# ABC-3TC-LPV/r                   133
# ABC-3TC-EFV                     116
# AZT-3TC-DTG                      99
# ABC-3TC-NVP                      95
# TDF-3TC-LPV/r                    88
# AZT-3TC-LPV/r                    47
# TDF-FTC-DTG                      36
# TDF-3TC-AZT                      29
# D4T-3TC-EFV                      21
# AZT-TDF-NVP                      14
# ABC-3TC-AZT                       9
# ABC-3TC-TDF                       5
# ABC-FTC-NVP                       4
# AZT-TDF-FTC-LPV/r                 4
# ABC-AZT-LPV/r                     3
# DDI-3TC-NVP                       3
# AZT-TDF-3TC-LPV/r                 2
# Dolutegravir                      2
# TDF-AZT-3TC-ATV/r                 2
# TDF-FTC-LPV/r                     2
# TDF-3TC-DRV/r                     1
# TDF-FTC-ATV/r                     1
# Adult 1st line ARV regimen        1
# DDI-3TC-EFV                       1
# Name: count, dtype: int64
#
# ViralLoadIndication
# Normal priority (status)          55377
# Initial                           14882
# Confirmation                       1090
# Repeat                              798
# PMTCT, 32 - 36 weeks gestation      103
# Immunologic failure                   5
# Clinical failure                      4
# 27-Jul-22                             1
# Name: count, dtype: int64
#
# DTGFirstPickUp
# TDF-3TC-DTG            81839
# ABC-3TC-DTG              986
# AZT-3TC-DTG              213
# TDF-FTC-DTG               92
# ABC-3TC-DTG-ATV/r          9
# TDF-3TC-DTG-LPV/r          5
# TDF-3TC-DTG-DRV-RTV        2
# ABC-FTC-DTG                1
# Name: count, dtype: int64
#
# CurrentARTStatus
# Active               73488
# LTFU                 24183
# Discontinued Care     7116
# Transferred out       3168
# Death                 2530
# Name: count, dtype: int64
#
# Biometric_Status
# Yes    73416
# No     37069
# Name: count, dtype: int64

# %%
# clean noticeable outliers from the categorical variables. 
data = data[(data['CurrentRegimenLine'] != 'One') | (data['CurrentRegimenLine'] != 'Two' )| (data['CurrentRegimenLine'] != 'AZT-3TC-DTG')]
data = data[data['TBStatus'] != '27-Jul-22']
data = data[(data['RegimenLineAtARTStart'] != 'One') | (data['RegimenLineAtARTStart'] != 'Three') | (data['RegimenLineAtARTStart'] != '30')]

# %%
# dealing with null values 
cat_null_value = list(data.select_dtypes(['O']).isnull().sum().index)
cat_null_value
# Out:
# ['ART_ID',
#  'Sex',
#  'RegimenLineAtARTStart',
#  'RegimenAtARTStart',
#  'CurrentRegimenLine',
#  'CurrentARTRegimen',
#  'ViralLoadIndication',
#  'TBStatus',
#  'DTGFirstPickUp',
#  'CurrentARTStatus',
#  'Appointment_Status',
#  'Biometric_Status']

# %%
# fill with mode according to the mode of each category of the target variable 
for col in cat_null_value: 
    cat_mode = data.groupby('CurrentARTStatus')[col].agg(pd.Series.mode)
    data[col] = data.apply(lambda row: cat_mode[row['CurrentARTStatus']] if pd.isnull(row[col]) else row[col], axis=1)

# %% [markdown]
# ### Treating Null values: Datetime

# %%
datetime_with_null_values = list(data.select_dtypes('datetime64[ns]').isnull().sum().index)
for col in datetime_with_null_values:
    data[col] = data[col].fillna(method = 'ffill')

# %%
data.isnull().sum()
# Out:
# ART_ID                        0
# Sex                           0
# current_Age                   0
# Age_At_Start                  0
# EnrollmentDate                0
# ART_Start_Date                0
# Clinic_Visit_Lastdate         0
# Pharmacy_LastPickupdate       0
# stamp_date                    0
# DaysOfARVRefill               0
# RegimenLineAtARTStart         0
# RegimenAtARTStart             0
# CurrentRegimenLine            0
# CurrentARTRegimen             0
# CurrentViralLoad              0
# DateofCurrentViralLoad        0
# LastDateOfSampleCollection    0
# ViralLoadReportedDate         0
# ViralLoadIndication           0
# CurrentWeight_Kg              0
# CurrentWeightDate             0
# CurrentHeight_cm              0
# CurrentHeightDate             0
# TBStatus                      0
# TBStatusDate                  0
# INHStartDate                  0
# DTGFirstPickUp                0
# DateofFirstDTGPickup          0
# CurrentARTStatus              0
# Appointment_Status            0
# Next_Visit_Date               0
# Next_Ap_by_pharmPill          0
# Next_Ap_by_careCard           0
# Days_To_Schedule              0
# Biometric_Status              0
# Biometric_date                0
# Date_Generated                0
# dtype: int64

# %%
data
# Out:
#                       ART_ID     Sex  current_Age  Age_At_Start  \
# 0           869-353-6611x171    Male         47.0          42.0
# 1          (883)724-7773x350  Female         33.0          27.0
# 2          (475)327-2157x798    Male         54.0          49.0
# 3               811.307.5336  Female         35.0          30.0
# 4               559.508.7048  Female         67.0          62.0
# ...                      ...     ...          ...           ...
# 110480       +1-743-530-7404    Male         39.0          30.0
# 110481      001-395-913-6457    Male         52.0          33.0
# 110482          377.902.4436    Male         37.0          33.0
# 110483      001-964-979-7249  Female         32.0          32.0
# 110484  001-397-291-9144x118  Female         29.0          29.0
#
#        EnrollmentDate ART_Start_Date Clinic_Visit_Lastdate  \
# 0          2017-08-03     2017-08-03            2022-03-10
# 1          2016-06-13     2016-06-13            2016-06-13
# 2          2017-06-29     2017-06-29            2022-04-14
# 3          2017-03-16     2017-03-17            2020-04-28
# 4          2017-05-25     2017-05-25            2022-04-28
# ...               ...            ...                   ...
# 110480     2013-10-02     2013-10-02            2022-08-24
# 110481     2022-05-11     2013-10-02            2022-08-24
# 110482     2022-08-24     2013-10-02            2022-08-24
# 110483     2022-08-24     2022-08-24            2022-08-24
# 110484     2022-08-26     2022-08-26            2022-08-26
#
#        Pharmacy_LastPickupdate          stamp_date  DaysOfARVRefill  ...  \
# 0                   2022-03-10 2022-03-11 12:57:00            180.0  ...
# 1                   2016-06-13 2017-09-28 00:00:00             14.0  ...
# 2                   2022-04-14 2022-04-14 11:34:00            180.0  ...
# 3                   2020-04-28 2020-05-01 10:37:00             90.0  ...
# 4                   2022-04-28 2022-04-28 15:34:00            180.0  ...
# ...                        ...                 ...              ...  ...
# 110480              2022-08-24 2022-08-24 15:07:00             90.0  ...
# 110481              2022-08-24 2022-08-24 15:07:00             30.0  ...
# 110482              2022-08-24 2022-08-24 15:07:00             30.0  ...
# 110483              2022-08-24 2022-08-25 09:38:00             90.0  ...
# 110484              2022-08-26 2022-08-26 15:26:00             90.0  ...
#
#        DateofFirstDTGPickup CurrentARTStatus Appointment_Status  \
# 0                2019-08-22           Active  Active With Drugs
# 1                2019-08-22             LTFU               LTFU
# 2                2017-06-29           Active  Active With Drugs
# 3                2019-08-15            Death               LTFU
# 4                2019-09-26           Active  Active With Drugs
# ...                     ...              ...                ...
# 110480           2022-08-24           Active  Active With Drugs
# 110481           2022-08-24             LTFU               LTFU
# 110482           2022-08-24             LTFU               LTFU
# 110483           2022-08-24           Active  Active With Drugs
# 110484           2022-08-26           Active  Active With Drugs
#
#        Next_Visit_Date  Next_Ap_by_pharmPill Next_Ap_by_careCard  \
# 0           2022-09-06            2022-09-06          2022-09-06
# 1           2016-07-13            2022-09-06          2022-09-06
# 2           2022-10-11            2022-10-11          2022-10-11
# 3           2020-07-27            2022-10-11          2020-07-23
# 4           2022-10-25            2022-10-25          2022-10-25
# ...                ...                   ...                 ...
# 110480      2022-11-22            2022-11-22          2022-11-25
# 110481      2022-11-22            2022-11-22          2022-11-25
# 110482      2022-11-22            2022-11-22          2022-11-25
# 110483      2022-11-22            2022-11-22          2022-11-23
# 110484      2022-11-24            2022-11-24          2022-11-25
#
#        Days_To_Schedule Biometric_Status Biometric_date      Date_Generated
# 0                  12.0              Yes     2021-01-07 2022-08-25 19:25:00
# 1               -2234.0               No     2021-01-07 2022-08-25 19:25:00
# 2                  47.0              Yes     2021-02-04 2022-08-25 19:25:00
# 3                -759.0               No     2021-02-04 2022-08-25 19:25:00
# 4                  61.0              Yes     2021-05-05 2022-08-25 19:25:00
# ...                 ...              ...            ...                 ...
# 110480             85.0              Yes     2022-08-24 2022-08-29 09:58:00
# 110481          -1942.5               No     2022-08-24 2022-08-29 09:58:00
# 110482          -1942.5              Yes     2022-08-25 2022-08-29 09:58:00
# 110483             85.0              Yes     2022-08-25 2022-08-29 09:58:00
# 110484             87.0              Yes     2022-08-26 2022-08-29 09:58:00
#
# [110484 rows x 37 columns]

# %% [markdown]
# ## Feature Selection

# %%
# Check correlation between variables
corr_matrix = data.select_dtypes(['int', 'float']).corr()
sns.heatmap(corr_matrix, annot = True)
plt.title('Correlation Between Variables')
plt.show()

# %%
# selection based on intuition
selected_data = data[['Sex', 'current_Age', 'Age_At_Start', 'DaysOfARVRefill', 'RegimenLineAtARTStart',
                      'RegimenAtARTStart', 'CurrentRegimenLine', 'CurrentARTRegimen',
                      'CurrentViralLoad', 'ViralLoadIndication', 'CurrentWeight_Kg', 'CurrentHeight_cm', 'TBStatus',
                      'CurrentARTStatus', 'Appointment_Status', 'Days_To_Schedule',
                      'Biometric_Status']]

# %%
# Selection by plotting feature importance using mutual info regression
from sklearn.feature_selection import mutual_info_classif

feature_data = selected_data.copy()
x = feature_data
y = feature_data.pop('CurrentARTStatus')

# Encoding Categorical variables
for col in feature_data.select_dtypes(['object', 'category']):
    x[col],_ = x[col].factorize()

# Encoding y variable
y,_ = y.factorize()

# %%
# Build Mutual Regression Model
#x = x.select_dtypes('int64')
mi_scores = mutual_info_classif(x,y, random_state = 42)
mi_scores = pd.Series(mi_scores, index = x.columns)
best_features = mi_scores.sort_values(ascending = False)

# Show features relationship to target variable
best_features.sort_values(ascending = True).plot(kind = 'barh')
plt.title('Feature Importance')
# Out:
# Text(0.5, 1.0, 'Feature Importance')

# %%
#plot distribution of categorical variable
data['CurrentARTStatus'].value_counts().plot.bar()
plt.title('Distribution of ART Status')
plt.xlabel('')
plt.show()

# %% [markdown]
# ### Feature Encoding

# %%
# show cardinality count
print('This counts number of unique value in the categorical variable\n')
for col in selected_data.select_dtypes('O'):
    print(f"{col} : {selected_data[col].value_counts().nunique()}\n")
# Out:
# This counts number of unique value in the categorical variable
#
# Sex : 2
#
# RegimenLineAtARTStart : 7
#
# RegimenAtARTStart : 29
#
# CurrentRegimenLine : 7
#
# CurrentARTRegimen : 28
#
# ViralLoadIndication : 7
#
# TBStatus : 6
#
# CurrentARTStatus : 5
#
# Appointment_Status : 4
#
# Biometric_Status : 2

# %%
# Encode Sex and Biometric_Status using binary encoding method
pred_data = selected_data.copy()
encoder = BinaryEncoder()
pred_data[['Sex_Female','Sex_Male',	'Biometric_Status_No','Biometric_Status_Yes']] = encoder.fit_transform(pred_data[['Sex', 'Biometric_Status']])

# %%
# Encode selected columns using get_dummies - one hot encoding technique
pred_data_encoded= pd.get_dummies(pred_data, columns=['RegimenLineAtARTStart', 'TBStatus', 'ViralLoadIndication', 
                                                      'CurrentRegimenLine', 'Appointment_Status'])
pred_data_encoded
# Out:
#            Sex  current_Age  Age_At_Start  DaysOfARVRefill RegimenAtARTStart  \
# 0         Male         47.0          42.0            180.0       AZT-3TC-NVP
# 1       Female         33.0          27.0             14.0       TDF-3TC-EFV
# 2         Male         54.0          49.0            180.0       AZT-3TC-NVP
# 3       Female         35.0          30.0             90.0       TDF-3TC-EFV
# 4       Female         67.0          62.0            180.0       AZT-3TC-NVP
# ...        ...          ...           ...              ...               ...
# 110480    Male         39.0          30.0             90.0       TDF-3TC-EFV
# 110481    Male         52.0          33.0             30.0       TDF-3TC-EFV
# 110482    Male         37.0          33.0             30.0       TDF-3TC-EFV
# 110483  Female         32.0          32.0             90.0       TDF-3TC-DTG
# 110484  Female         29.0          29.0             90.0       TDF-3TC-DTG
#
#        CurrentARTRegimen  CurrentViralLoad  CurrentWeight_Kg  \
# 0            TDF-3TC-DTG              19.0              95.0
# 1            TDF-3TC-EFV              30.0              56.0
# 2            TDF-3TC-DTG              19.0              80.0
# 3            TDF-3TC-DTG              19.0              40.0
# 4            TDF-3TC-DTG               0.0              77.0
# ...                  ...               ...               ...
# 110480       TDF-3TC-DTG              10.0              49.0
# 110481       TDF-3TC-EFV              30.0              56.0
# 110482       TDF-3TC-EFV              30.0              56.0
# 110483       TDF-3TC-DTG              10.0              62.0
# 110484       TDF-3TC-DTG              10.0              53.0
#
#         CurrentHeight_cm CurrentARTStatus  ...  \
# 0                  170.0           Active  ...
# 1                  161.0             LTFU  ...
# 2                  160.0           Active  ...
# 3                  162.0            Death  ...
# 4                  165.0           Active  ...
# ...                  ...              ...  ...
# 110480             162.0           Active  ...
# 110481             161.0             LTFU  ...
# 110482             161.0             LTFU  ...
# 110483             155.0           Active  ...
# 110484             165.0           Active  ...
#
#         CurrentRegimenLine_Adult 3rd Line ARV Regimens  \
# 0                                                False
# 1                                                False
# 2                                                False
# 3                                                False
# 4                                                False
# ...                                                ...
# 110480                                           False
# 110481                                           False
# 110482                                           False
# 110483                                           False
# 110484                                           False
#
#        CurrentRegimenLine_Child 1st line ARV regimen  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
# ...                                              ...
# 110480                                         False
# 110481                                         False
# 110482                                         False
# 110483                                         False
# 110484                                         False
#
#         CurrentRegimenLine_Child 2nd line ARV regimen  \
# 0                                               False
# 1                                               False
# 2                                               False
# 3                                               False
# 4                                               False
# ...                                               ...
# 110480                                          False
# 110481                                          False
# 110482                                          False
# 110483                                          False
# 110484                                          False
#
#         CurrentRegimenLine_Child 3rd Line ARV Regimens  \
# 0                                                False
# 1                                                False
# 2                                                False
# 3                                                False
# 4                                                False
# ...                                                ...
# 110480                                           False
# 110481                                           False
# 110482                                           False
# 110483                                           False
# 110484                                           False
#
#         CurrentRegimenLine_One  CurrentRegimenLine_Two  \
# 0                        False                   False
# 1                        False                   False
# 2                        False                   False
# 3                        False                   False
# 4                        False                   False
# ...                        ...                     ...
# 110480                   False                   False
# 110481                   False                   False
# 110482                   False                   False
# 110483                   False                   False
# 110484                   False                   False
#
#         Appointment_Status_Active With Drugs  Appointment_Status_LTFU  \
# 0                                       True                    False
# 1                                      False                     True
# 2                                       True                    False
# 3                                      False                     True
# 4                                       True                    False
# ...                                      ...                      ...
# 110480                                  True                    False
# 110481                                 False                     True
# 110482                                 False                     True
# 110483                                  True                    False
# 110484                                  True                    False
#
#         Appointment_Status_Missed Appointment  Appointment_Status_Today Visit
# 0                                       False                           False
# 1                                       False                           False
# 2                                       False                           False
# 3                                       False                           False
# 4                                       False                           False
# ...                                       ...                             ...
# 110480                                  False                           False
# 110481                                  False                           False
# 110482                                  False                           False
# 110483                                  False                           False
# 110484                                  False                           False
#
# [110484 rows x 48 columns]

# %%
# calculate frequency of each category and encode using those frequencies - Frequency Encoding 
regimen_at_start_freq = pred_data_encoded['RegimenAtARTStart'].value_counts(normalize=True)
current_art_regimen_freq = pred_data_encoded['CurrentARTRegimen'].value_counts(normalize=True)

# Replace categories with frequencies
pred_data_encoded['RegimenAtARTStart'] = pred_data_encoded['RegimenAtARTStart'].map(regimen_at_start_freq)
pred_data_encoded['CurrentARTRegimen'] = pred_data_encoded['CurrentARTRegimen'].map(current_art_regimen_freq)

# %%
pred_data_encoded
# Out:
#            Sex  current_Age  Age_At_Start  DaysOfARVRefill  RegimenAtARTStart  \
# 0         Male         47.0          42.0            180.0           0.089968
# 1       Female         33.0          27.0             14.0           0.256951
# 2         Male         54.0          49.0            180.0           0.089968
# 3       Female         35.0          30.0             90.0           0.256951
# 4       Female         67.0          62.0            180.0           0.089968
# ...        ...          ...           ...              ...                ...
# 110480    Male         39.0          30.0             90.0           0.256951
# 110481    Male         52.0          33.0             30.0           0.256951
# 110482    Male         37.0          33.0             30.0           0.256951
# 110483  Female         32.0          32.0             90.0           0.584130
# 110484  Female         29.0          29.0             90.0           0.584130
#
#         CurrentARTRegimen  CurrentViralLoad  CurrentWeight_Kg  \
# 0                0.759042              19.0              95.0
# 1                0.150130              30.0              56.0
# 2                0.759042              19.0              80.0
# 3                0.759042              19.0              40.0
# 4                0.759042               0.0              77.0
# ...                   ...               ...               ...
# 110480           0.759042              10.0              49.0
# 110481           0.150130              30.0              56.0
# 110482           0.150130              30.0              56.0
# 110483           0.759042              10.0              62.0
# 110484           0.759042              10.0              53.0
#
#         CurrentHeight_cm CurrentARTStatus  ...  \
# 0                  170.0           Active  ...
# 1                  161.0             LTFU  ...
# 2                  160.0           Active  ...
# 3                  162.0            Death  ...
# 4                  165.0           Active  ...
# ...                  ...              ...  ...
# 110480             162.0           Active  ...
# 110481             161.0             LTFU  ...
# 110482             161.0             LTFU  ...
# 110483             155.0           Active  ...
# 110484             165.0           Active  ...
#
#         CurrentRegimenLine_Adult 3rd Line ARV Regimens  \
# 0                                                False
# 1                                                False
# 2                                                False
# 3                                                False
# 4                                                False
# ...                                                ...
# 110480                                           False
# 110481                                           False
# 110482                                           False
# 110483                                           False
# 110484                                           False
#
#        CurrentRegimenLine_Child 1st line ARV regimen  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
# ...                                              ...
# 110480                                         False
# 110481                                         False
# 110482                                         False
# 110483                                         False
# 110484                                         False
#
#         CurrentRegimenLine_Child 2nd line ARV regimen  \
# 0                                               False
# 1                                               False
# 2                                               False
# 3                                               False
# 4                                               False
# ...                                               ...
# 110480                                          False
# 110481                                          False
# 110482                                          False
# 110483                                          False
# 110484                                          False
#
#         CurrentRegimenLine_Child 3rd Line ARV Regimens  \
# 0                                                False
# 1                                                False
# 2                                                False
# 3                                                False
# 4                                                False
# ...                                                ...
# 110480                                           False
# 110481                                           False
# 110482                                           False
# 110483                                           False
# 110484                                           False
#
#         CurrentRegimenLine_One  CurrentRegimenLine_Two  \
# 0                        False                   False
# 1                        False                   False
# 2                        False                   False
# 3                        False                   False
# 4                        False                   False
# ...                        ...                     ...
# 110480                   False                   False
# 110481                   False                   False
# 110482                   False                   False
# 110483                   False                   False
# 110484                   False                   False
#
#         Appointment_Status_Active With Drugs  Appointment_Status_LTFU  \
# 0                                       True                    False
# 1                                      False                     True
# 2                                       True                    False
# 3                                      False                     True
# 4                                       True                    False
# ...                                      ...                      ...
# 110480                                  True                    False
# 110481                                 False                     True
# 110482                                 False                     True
# 110483                                  True                    False
# 110484                                  True                    False
#
#         Appointment_Status_Missed Appointment  Appointment_Status_Today Visit
# 0                                       False                           False
# 1                                       False                           False
# 2                                       False                           False
# 3                                       False                           False
# 4                                       False                           False
# ...                                       ...                             ...
# 110480                                  False                           False
# 110481                                  False                           False
# 110482                                  False                           False
# 110483                                  False                           False
# 110484                                  False                           False
#
# [110484 rows x 48 columns]

# %%
# drop Sex column
pred_data_encoded = pred_data_encoded.drop(['Sex', 'Biometric_Status'], axis = 1)

# %%
# replace True and False values with 1 and 0
pred_data_encoded.replace({True: 1, False: 0}, inplace=True)

# %%
# deal with column headers
pred_data_encoded.columns = pred_data_encoded.columns.str.replace(' ', '_', regex=False)
pred_data_encoded.rename(columns = {'ViralLoadIndication_Normal_priority_(status)': 'ViralLoadIndication_Normal_priority_status'}, inplace = True)
pred_data_encoded.columns
# Out:
# Index(['current_Age', 'Age_At_Start', 'DaysOfARVRefill', 'RegimenAtARTStart',
#        'CurrentARTRegimen', 'CurrentViralLoad', 'CurrentWeight_Kg',
#        'CurrentHeight_cm', 'CurrentARTStatus', 'Days_To_Schedule',
#        'Sex_Female', 'Sex_Male', 'Biometric_Status_No', 'Biometric_Status_Yes',
#        'RegimenLineAtARTStart_Adult_1st_line_ARV_regimen',
#        'RegimenLineAtARTStart_Adult_2nd_line_ARV_regimen',
#        'RegimenLineAtARTStart_Adult_3rd_Line_ARV_Regimens',
#        'RegimenLineAtARTStart_Child_1st_line_ARV_regimen',
#        'RegimenLineAtARTStart_Child_2nd_line_ARV_regimen',
#        'RegimenLineAtARTStart_One', 'RegimenLineAtARTStart_Three',
#        'TBStatus_Completed_treatment_for_disease',
#        'TBStatus_Currently_on_INH_prophylaxis', 'TBStatus_Disease_diagnosed',
#        'TBStatus_Disease_suspected',
#        'TBStatus_No_signs_or_symptoms_of_disease',
#        'TBStatus_On_treatment_for_disease',
#        'ViralLoadIndication_Clinical_failure',
#        'ViralLoadIndication_Confirmation',
#        'ViralLoadIndication_Immunologic_failure',
#        'ViralLoadIndication_Initial',
#        'ViralLoadIndication_Normal_priority_status',
#        'ViralLoadIndication_PMTCT,_32_-_36_weeks_gestation',
#        'ViralLoadIndication_Repeat',
#        'CurrentRegimenLine_Adult_1st_line_ARV_regimen',
#        'CurrentRegimenLine_Adult_2nd_line_ARV_regimen',
#        'CurrentRegimenLine_Adult_3rd_Line_ARV_Regimens',
#        'CurrentRegimenLine_Child_1st_line_ARV_regimen',
#        'CurrentRegimenLine_Child_2nd_line_ARV_regimen',
#        'CurrentRegimenLine_Child_3rd_Line_ARV_Regimens',
#        'CurrentRegimenLine_One', 'CurrentRegimenLine_Two',
#        'Appointment_Status_Active_With_Drugs', 'Appointment_Status_LTFU',
#        'Appointment_Status_Missed_Appointment',
#        'Appointment_Status_Today_Visit'],
#       dtype='object')

# %%
pred_data_encoded.rename(columns = {'ViralLoadIndication_PMTCT,_32_-_36_weeks_gestation': 'ViralLoadIndication_PMTCT_32_36_weeks_gestation'}, inplace = True)

# %%
# Save data
pred_data_encoded.to_csv('new_ART_data.csv', index = False)

# %% [markdown]
# ### Model_building

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.metrics import classification_report, confusion_matrix

# %%
# Separate into independent and response variable
ART_data = pred_data_encoded.copy()
x = ART_data
y = ART_data.pop('CurrentARTStatus')

# %%
# Train-Test Split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Model Selection
models = {
    'Logistic_Regression': LogisticRegression(),
    'Decision_Tree': DecisionTreeClassifier(),
    'Random_Forest': RandomForestClassifier(),
    'Gradient_Boosting': GradientBoostingClassifier()
}

# Model Training and Evaluation
for model_name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    print(f"{model_name} Classification Report:")
    print(classification_report(y_test, y_pred))
    print(confusion_matrix(y_test, y_pred))
# Out:
# Logistic_Regression Classification Report:
#                    precision    recall  f1-score   support
#
#            Active       0.99      1.00      0.99     14784
#             Death       0.36      0.11      0.16       490
# Discontinued Care       0.63      0.67      0.65      1425
#              LTFU       0.85      0.94      0.89      4785
#   Transferred out       0.35      0.11      0.17       613
#
#          accuracy                           0.92     22097
#         macro avg       0.64      0.56      0.57     22097
#      weighted avg       0.90      0.92      0.91     22097
#
# [[14776     5     1     2     0]
#  [   26    52    75   312    25]
#  [   33    27   956   355    54]
#  [  100    39   116  4488    42]
#  [   42    20   375   110    66]]
# Decision_Tree Classification Report:
#                    precision    recall  f1-score   support
#
#            Active       1.00      0.99      0.99     14784
#             Death       0.72      0.71      0.72       490
# Discontinued Care       0.79      0.80      0.79      1425
#              LTFU       0.97      0.97      0.97      4785
#   Transferred out       0.45      0.48      0.46       613
#
#          accuracy                           0.95     22097
#         macro avg       0.78      0.79      0.79     22097
#      weighted avg       0.95      0.95      0.95     22097
#
# [[14653    24    39     4    64]
#  [   19   350    35    44    42]
#  [   19    31  1134    50   191]
#  [    9    33    51  4636    56]
#  [   26    50   185    60   292]]
# Random_Forest Classification Report:
#                    precision    recall  f1-score   support
#
#            Active       0.99      1.00      1.00     14784
#             Death       0.79      0.71      0.75       490
# Discontinued Care       0.84      0.83      0.83      1425
#              LTFU       0.97      0.98      0.97      4785
#   Transferred out       0.60      0.53      0.56       613
#
#          accuracy                           0.96     22097
#         macro avg       0.84      0.81      0.82     22097
#      weighted avg       0.96      0.96      0.96     22097
#
# [[14784     0     0     0     0]
#  [   23   350    29    44    44]
#  [   21    31  1178    57   138]
#  [   15    27    37  4668    38]
#  [   28    37   164    59   325]]
# Gradient_Boosting Classification Report:
#                    precision    recall  f1-score   support
#
#            Active       1.00      1.00      1.00     14784
#             Death       0.82      0.74      0.78       490
# Discontinued Care       0.84      0.84      0.84      1425
#              LTFU       0.97      0.98      0.97      4785
#   Transferred out       0.56      0.51      0.54       613
#
#          accuracy                           0.97     22097
#         macro avg       0.84      0.81      0.83     22097
#      weighted avg       0.96      0.97      0.96     22097
#
# [[14783     0     0     1     0]
#  [   15   364    23    39    49]
#  [   20    27  1196    43   139]
#  [    8    18    29  4672    58]
#  [   28    34   169    67   315]]

# %% [markdown]
# ### Fit Random Forest with different hyperparameters

# %%
X_train = X_train[top_features]
X_train
# Out:
#         Days_To_Schedule  Appointment_Status_LTFU  CurrentViralLoad  \
# 43456              130.0                        0              19.0
# 56043               87.0                        0              10.0
# 10062            -1687.0                        1              30.0
# 75670            -1942.5                        1              30.0
# 40246               44.0                        0               0.0
# ...                  ...                      ...               ...
# 76820             -647.0                        1              20.0
# 110269              12.0                        0              19.0
# 103695           -1942.5                        1              30.0
# 860                108.0                        0              19.0
# 15795               59.0                        0               5.0
#
#         Appointment_Status_Active_With_Drugs  Biometric_Status_No  \
# 43456                                      1                    0
# 56043                                      1                    0
# 10062                                      0                    1
# 75670                                      0                    1
# 40246                                      1                    0
# ...                                      ...                  ...
# 76820                                      0                    1
# 110269                                     1                    0
# 103695                                     0                    1
# 860                                        1                    0
# 15795                                      1                    0
#
#         DaysOfARVRefill  CurrentHeight_cm  CurrentARTRegimen  \
# 43456             180.0             173.0           0.759042
# 56043             180.0             161.0           0.759042
# 10062              60.0             173.0           0.150130
# 75670              30.0             161.0           0.150130
# 40246             180.0             183.0           0.759042
# ...                 ...               ...                ...
# 76820              90.0             162.0           0.759042
# 110269            120.0             175.0           0.759042
# 103695             30.0             161.0           0.150130
# 860               180.0             142.0           0.759042
# 15795             180.0             166.0           0.759042
#
#         Biometric_Status_Yes  CurrentWeight_Kg  RegimenAtARTStart  \
# 43456                      1              70.0           0.584130
# 56043                      1              78.0           0.584130
# 10062                      0              45.0           0.256951
# 75670                      0              56.0           0.256951
# 40246                      1              72.0           0.584130
# ...                      ...               ...                ...
# 76820                      0              55.0           0.584130
# 110269                     1              58.0           0.584130
# 103695                     0              46.0           0.256951
# 860                        1              59.0           0.584130
# 15795                      1              73.0           0.584130
#
#         Age_At_Start  current_Age  ViralLoadIndication_Initial  \
# 43456           22.0         23.0                            1
# 56043           23.0         24.0                            1
# 10062           30.0         36.0                            0
# 75670           33.0         44.0                            0
# 40246           20.0         22.0                            0
# ...              ...          ...                          ...
# 76820           45.0         47.0                            0
# 110269          52.0         53.0                            0
# 103695          33.0         40.0                            0
# 860             28.0         36.0                            0
# 15795           34.0         43.0                            0
#
#         ViralLoadIndication_Normal_priority_status  \
# 43456                                            0
# 56043                                            0
# 10062                                            1
# 75670                                            1
# 40246                                            1
# ...                                            ...
# 76820                                            1
# 110269                                           1
# 103695                                           1
# 860                                              1
# 15795                                            1
#
#         Appointment_Status_Missed_Appointment  Sex_Female  Sex_Male
# 43456                                       0           0         1
# 56043                                       0           0         1
# 10062                                       0           1         0
# 75670                                       0           0         1
# 40246                                       0           0         1
# ...                                       ...         ...       ...
# 76820                                       0           1         0
# 110269                                      0           0         1
# 103695                                      0           1         0
# 860                                         0           1         0
# 15795                                       0           1         0
#
# [88387 rows x 18 columns]

# %%
# Fit model
random_forest = RandomForestClassifier()
random_forest.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
random_forest.feature_names_in_
# Out:
# array(['Days_To_Schedule', 'Appointment_Status_LTFU', 'CurrentViralLoad',
#        'Appointment_Status_Active_With_Drugs', 'Biometric_Status_No',
#        'DaysOfARVRefill', 'CurrentHeight_cm', 'CurrentARTRegimen',
#        'Biometric_Status_Yes', 'CurrentWeight_Kg', 'RegimenAtARTStart',
#        'Age_At_Start', 'current_Age', 'ViralLoadIndication_Initial',
#        'ViralLoadIndication_Normal_priority_status',
#        'Appointment_Status_Missed_Appointment', 'Sex_Female', 'Sex_Male'],
#       dtype=object)

# %%
feature_importance = {}
importance = random_forest.feature_importances_
indices = np.argsort(importance)[::-1]
for f in range(X_train.shape[1]):
    feature_name = X_train.columns[indices[f]]
    importance_value = importance[indices[f]]
    feature_importance[feature_name] = importance_value

fi_data = list(feature_importance.items())
fi_data
feature_importance_df = pd.DataFrame(fi_data, columns=['Feature', 'Importance'])
top_features = feature_importance_df['Feature'][0:18].to_list()

# %% [markdown]
# ## Implementing SMOTE in the under sampled response variable

# %%
from imblearn.over_sampling import SMOTE

# %%
#majority_class = max(y_train.value_counts().index)
#num_samples_majority = len(y_train[y_train == majority_class])

# Create a sampling strategy dictionary
#sampling_strategy = {'Active': num_samples_majority} 
sm = SMOTE(random_state = 42)
X_train_res, y_train_res = sm.fit_resample(X_train, y_train)

# %%
y_train_res.value_counts()
# Out:
# CurrentARTStatus
# Active               58703
# LTFU                 58703
# Transferred out      58703
# Death                58703
# Discontinued Care    58703
# Name: count, dtype: int64

# %%
# Train a model
random_forest_res = RandomForestClassifier()
random_forest_res.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
ypred = random_forest_res.predict(X_test)

# %%
print(classification_report(y_test, ypred))
print(confusion_matrix(y_test, ypred))

# %% [markdown]
# ### Save Model

# %%
import pickle

# %%
with open('new_ART_RF_Model1.pkl', 'wb') as f:
    pickle.dump(random_forest, f)
